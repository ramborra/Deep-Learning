# %% [markdown]
# # Deep Learning
# ## Assignment 4
# Previously in 2_fullyconnected.ipynb and 3_regularization.ipynb, we trained fully connected networks to classify notMNIST characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
#
# * convolutions need the image data formatted as a cube (width by height by #channels)
# * labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Random Seed  
  tf.set_random_seed(42)  
    
  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.878395
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.5%
# Minibatch loss at step 50: 1.646402
# Minibatch accuracy: 31.2%
# Validation accuracy: 56.7%
# Minibatch loss at step 100: 0.629248
# Minibatch accuracy: 81.2%
# Validation accuracy: 72.3%
# Minibatch loss at step 150: 1.544412
# Minibatch accuracy: 56.2%
# Validation accuracy: 69.0%
# Minibatch loss at step 200: 1.669333
# Minibatch accuracy: 43.8%
# Validation accuracy: 72.9%
# Minibatch loss at step 250: 0.961547
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.6%
# Minibatch loss at step 300: 1.263107
# Minibatch accuracy: 62.5%
# Validation accuracy: 79.8%
# Minibatch loss at step 350: 0.368872
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.1%
# Minibatch loss at step 400: 0.528980
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.3%
# Minibatch loss at step 450: 0.344425
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.7%
# Minibatch loss at step 500: 0.248951
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.5%
# Minibatch loss at step 550: 0.563963
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.9%
# Minibatch loss at step 600: 0.892719
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.1%
# Minibatch loss at step 650: 0.798849
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.3%
# Minibatch loss at step 700: 0.471918
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.5%
# Minibatch loss at step 750: 0.417864
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.6%
# Minibatch loss at step 800: 0.220975
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 850: 1.129349
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.7%
# Minibatch loss at step 900: 0.603646
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 950: 0.348696
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.4%
# Minibatch loss at step 1000: 0.378164
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Test accuracy: 89.3%

# %% [markdown]
# ## Problem 1
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (nn.max_pool()) of stride 2 and kernel size 2.
#
#
# * Both of the approaches (strides and pooling) reduce the dimensionality of the input (for strides/pooling size > 1). This by itself is a good thing because it reduces the computation time, number of parameters and allows to prevent overfitting.
#
# * Reducing the input dimensionality is something you want because it forces the network to project its learned representations in a different and with lower dimensionality space. This is good computationally speaking because you have to allocate less memory and thus you can have bigger batches. But it's also something desirable because usually high-dimensional spaces have a lot of redundancy and are spaces in which all abjects appears to be sparse and dissimilar
#
# * you can think about strides as downsampling the result of the 1-strided convolution by just taking every s-th result. max-pooling downsamples the result by taking the maximum number from a hypercube. If some important feature has been found, max-pool preserves it regardless of its position
#
# * maxpooling forces the network to learn particular features, depending on the type of pooling you apply.
#
# * The function you decide to use for the pooling operation, moreover, can force the network to give more importance to some features.
#
# * Max-pooling, for instance, is widely used because allow the network to be robust to small variations of the input image.
#
# * What happens, in practice, it that only the features with the highest activations pass through the max-pooling gate. If the input image is shifted by a small amount, then the max-pooling op produces the same output although the input is shifted (the maximum shift is thus equal to the kernel size).
#
# * CNN without pooling are also capable of learning this kind of features, but with a bigger cost in term of parameters and computing time

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():
    
  # Random Seed  
  tf.set_random_seed(42)   

  # Input data.
  tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal([image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    
    
    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.042297
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.041883
# Minibatch accuracy: 12.5%
# Validation accuracy: 28.9%
# Minibatch loss at step 100: 0.750566
# Minibatch accuracy: 68.8%
# Validation accuracy: 67.2%
# Minibatch loss at step 150: 1.434590
# Minibatch accuracy: 56.2%
# Validation accuracy: 67.2%
# Minibatch loss at step 200: 1.235511
# Minibatch accuracy: 68.8%
# Validation accuracy: 74.1%
# Minibatch loss at step 250: 0.669600
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.4%
# Minibatch loss at step 300: 1.134165
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.5%
# Minibatch loss at step 350: 0.287982
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 400: 0.519595
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 450: 0.384158
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.1%
# Minibatch loss at step 500: 0.237474
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.8%
# Minibatch loss at step 550: 0.638928
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.0%
# Minibatch loss at step 600: 0.869937
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 650: 0.625272
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.5%
# Minibatch loss at step 700: 0.286067
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.7%
# Minibatch loss at step 750: 0.620357
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 800: 0.162242
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.0%
# Minibatch loss at step 850: 1.132850
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.2%
# Minibatch loss at step 900: 0.628670
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.3%
# Minibatch loss at step 950: 0.181566
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.4%
# Minibatch loss at step 1000: 0.406491
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.0%
# Test accuracy: 90.3%

# %% [markdown]
# # Problem 2
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic LeNet5 architecture, adding Dropout, and/or adding learning rate decay.
#
# Reference : https://smist08.wordpress.com/2016/10/04/the-road-to-tensorflow-part-10-more-on-optimization/
#
# https://github.com/tensorflow/tensorflow/blob/7e3b8b23835ab0ac55d390aed2349af6e05dbe3b/tensorflow/models/image/mnist/convolutional.py#L216

# %%
batch_size = 64
patch_size = 5
depth = 32
num_hidden = 64
SEED=42

graph = tf.Graph()

with graph.as_default():
    
  # Random Seed  
  tf.set_random_seed(42)   

  # Input data.
  tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1,seed=SEED))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1,seed=SEED))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal([image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1,seed=SEED))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1,seed=SEED))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    
    
    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    hidden = tf.nn.dropout(hidden, 0.5, seed=SEED)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  train_size = train_labels.shape[0]  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))

  # L2 regularization for the fully connected parameters.
  regularizers = (tf.nn.l2_loss(layer1_weights) + tf.nn.l2_loss(layer1_biases) +
                  tf.nn.l2_loss(layer2_weights) + tf.nn.l2_loss(layer2_biases) +
                  tf.nn.l2_loss(layer3_weights) + tf.nn.l2_loss(layer3_biases) +
                  tf.nn.l2_loss(layer4_weights) + tf.nn.l2_loss(layer4_biases))
  # Add the regularization term to the loss.
  loss += 5e-4 * regularizers

  # Optimizer: set up a variable that's incremented once per batch and
  # controls the learning rate decay.
  batch = tf.Variable(0)
  # Decay once per epoch, using an exponential schedule starting at 0.01.
  learning_rate = tf.train.exponential_decay(
      0.01,                # Base learning rate.
      batch * batch_size,  # Current index into the dataset.
      train_size,          # Decay step.
      0.95,                # Decay rate.
      staircase=True)
  # Use simple momentum for the optimization.
  optimizer = tf.train.MomentumOptimizer(learning_rate,
                                         0.9).minimize(loss,
                                                       global_step=batch)
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001
num_epochs = 10

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  #for step in range(num_steps):
  for step in xrange(int(num_epochs * train_size) // batch_size):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 6.820992
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.4%
# Minibatch loss at step 50: 2.522034
# Minibatch accuracy: 9.4%
# Validation accuracy: 11.6%
# Minibatch loss at step 100: 2.182222
# Minibatch accuracy: 29.7%
# Validation accuracy: 29.0%
# Minibatch loss at step 150: 1.836490
# Minibatch accuracy: 40.6%
# Validation accuracy: 48.1%
# Minibatch loss at step 200: 1.434090
# Minibatch accuracy: 57.8%
# Validation accuracy: 55.1%
# Minibatch loss at step 250: 1.234791
# Minibatch accuracy: 64.1%
# Validation accuracy: 62.7%
# Minibatch loss at step 300: 1.137870
# Minibatch accuracy: 70.3%
# Validation accuracy: 64.9%
# Minibatch loss at step 350: 1.573621
# Minibatch accuracy: 60.9%
# Validation accuracy: 65.8%
# Minibatch loss at step 400: 1.163043
# Minibatch accuracy: 70.3%
# Validation accuracy: 67.7%
# Minibatch loss at step 450: 1.134970
# Minibatch accuracy: 73.4%
# Validation accuracy: 70.9%
# Minibatch loss at step 500: 1.389763
# Minibatch accuracy: 67.2%
# Validation accuracy: 71.8%
# Minibatch loss at step 550: 1.206550
# Minibatch accuracy: 71.9%
# Validation accuracy: 73.4%
# Minibatch loss at step 600: 0.924190
# Minibatch accuracy: 79.7%
# Validation accuracy: 73.5%
# Minibatch loss at step 650: 1.329980
# Minibatch accuracy: 70.3%
# Validation accuracy: 75.3%
# Minibatch loss at step 700: 1.186957
# Minibatch accuracy: 78.1%
# Validation accuracy: 75.4%
# Minibatch loss at step 750: 1.160491
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.7%
# Minibatch loss at step 800: 0.929587
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.5%
# Minibatch loss at step 850: 1.037436
# Minibatch accuracy: 70.3%
# Validation accuracy: 77.1%
# Minibatch loss at step 900: 1.090501
# Minibatch accuracy: 71.9%
# Validation accuracy: 77.3%
# Minibatch loss at step 950: 1.128620
# Minibatch accuracy: 73.4%
# Validation accuracy: 77.5%
# Minibatch loss at step 1000: 1.136270
# Minibatch accuracy: 67.2%
# Validation accuracy: 77.4%
# Minibatch loss at step 1050: 0.957209
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.1%
# Minibatch loss at step 1100: 0.876682
# Minibatch accuracy: 82.8%
# Validation accuracy: 77.3%
# Minibatch loss at step 1150: 0.997628
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.8%
# Minibatch loss at step 1200: 1.193827
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.3%
# Minibatch loss at step 1250: 0.880584
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.5%
# Minibatch loss at step 1300: 0.894259
# Minibatch accuracy: 79.7%
# Validation accuracy: 79.3%
# Minibatch loss at step 1350: 0.698404
# Minibatch accuracy: 85.9%
# Validation accuracy: 79.4%
# Minibatch loss at step 1400: 0.922419
# Minibatch accuracy: 79.7%
# Validation accuracy: 80.3%
# Minibatch loss at step 1450: 1.036444
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.8%
# Minibatch loss at step 1500: 1.009536
# Minibatch accuracy: 76.6%
# Validation accuracy: 79.7%
# Minibatch loss at step 1550: 0.897676
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.5%
# Minibatch loss at step 1600: 0.973599
# Minibatch accuracy: 78.1%
# Validation accuracy: 80.8%
# Minibatch loss at step 1650: 0.699829
# Minibatch accuracy: 89.1%
# Validation accuracy: 80.2%
# Minibatch loss at step 1700: 0.652875
# Minibatch accuracy: 85.9%
# Validation accuracy: 81.4%
# Minibatch loss at step 1750: 0.894419
# Minibatch accuracy: 84.4%
# Validation accuracy: 81.3%
# Minibatch loss at step 1800: 0.825105
# Minibatch accuracy: 82.8%
# Validation accuracy: 80.8%
# Minibatch loss at step 1850: 0.944321
# Minibatch accuracy: 82.8%
# Validation accuracy: 81.4%
# Minibatch loss at step 1900: 0.633861
# Minibatch accuracy: 89.1%
# Validation accuracy: 81.8%
# Minibatch loss at step 1950: 0.797806
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 2000: 0.824012
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 2050: 0.867423
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.9%
# Minibatch loss at step 2100: 0.500121
# Minibatch accuracy: 92.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 2150: 0.712185
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 2200: 0.930642
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 2250: 0.783945
# Minibatch accuracy: 84.4%
# Validation accuracy: 81.8%
# Minibatch loss at step 2300: 0.916402
# Minibatch accuracy: 78.1%
# Validation accuracy: 82.8%
# Minibatch loss at step 2350: 0.715504
# Minibatch accuracy: 84.4%
# Validation accuracy: 82.7%
# Minibatch loss at step 2400: 1.167083
# Minibatch accuracy: 76.6%
# Validation accuracy: 82.6%
# Minibatch loss at step 2450: 0.736059
# Minibatch accuracy: 85.9%
# Validation accuracy: 82.8%
# Minibatch loss at step 2500: 0.982880
# Minibatch accuracy: 78.1%
# Validation accuracy: 82.6%
# Minibatch loss at step 2550: 1.125971
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 2600: 0.793164
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.0%
# Minibatch loss at step 2650: 0.834530
# Minibatch accuracy: 82.8%
# Validation accuracy: 82.5%
# Minibatch loss at step 2700: 0.873560
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.3%
# Minibatch loss at step 2750: 0.840452
# Minibatch accuracy: 82.8%
# Validation accuracy: 83.1%
# Minibatch loss at step 2800: 0.650252
# Minibatch accuracy: 84.4%
# Validation accuracy: 82.6%
# Minibatch loss at step 2850: 0.831479
# Minibatch accuracy: 82.8%
# Validation accuracy: 82.7%
# Minibatch loss at step 2900: 0.801021
# Minibatch accuracy: 85.9%
# Validation accuracy: 82.3%
# Minibatch loss at step 2950: 0.511443
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.8%
# Minibatch loss at step 3000: 0.755892
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.2%
# Minibatch loss at step 3050: 0.602326
# Minibatch accuracy: 92.2%
# Validation accuracy: 83.1%
# Minibatch loss at step 3100: 0.678394
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.5%
# Minibatch loss at step 3150: 0.907543
# Minibatch accuracy: 82.8%
# Validation accuracy: 83.3%
# Minibatch loss at step 3200: 0.834021
# Minibatch accuracy: 82.8%
# Validation accuracy: 83.7%
# Minibatch loss at step 3250: 0.536043
# Minibatch accuracy: 95.3%
# Validation accuracy: 83.4%
# Minibatch loss at step 3300: 0.570783
# Minibatch accuracy: 95.3%
# Validation accuracy: 83.8%
# Minibatch loss at step 3350: 0.778398
# Minibatch accuracy: 90.6%
# Validation accuracy: 83.3%
# Minibatch loss at step 3400: 0.809200
# Minibatch accuracy: 76.6%
# Validation accuracy: 83.7%
# Minibatch loss at step 3450: 0.682723
# Minibatch accuracy: 89.1%
# Validation accuracy: 84.2%
# Minibatch loss at step 3500: 0.727026
# Minibatch accuracy: 82.8%
# Validation accuracy: 84.4%
# Minibatch loss at step 3550: 0.542543
# Minibatch accuracy: 89.1%
# Validation accuracy: 84.4%
# Minibatch loss at step 3600: 0.706698
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.7%
# Minibatch loss at step 3650: 0.768180
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.3%
# Minibatch loss at step 3700: 0.837619
# Minibatch accuracy: 82.8%
# Validation accuracy: 84.4%
# Minibatch loss at step 3750: 0.577289
# Minibatch accuracy: 89.1%
# Validation accuracy: 84.1%
# Minibatch loss at step 3800: 0.775270
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.6%
# Minibatch loss at step 3850: 0.993881
# Minibatch accuracy: 82.8%
# Validation accuracy: 84.4%
# Minibatch loss at step 3900: 0.607993
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.9%
# Minibatch loss at step 3950: 0.637644
# Minibatch accuracy: 89.1%
# Validation accuracy: 84.6%
# Minibatch loss at step 4000: 0.756706
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.1%
# Minibatch loss at step 4050: 0.821494
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.0%
# Minibatch loss at step 4100: 0.682827
# Minibatch accuracy: 82.8%
# Validation accuracy: 84.5%
# Minibatch loss at step 4150: 0.688341
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.6%
# Minibatch loss at step 4200: 0.512263
# Minibatch accuracy: 89.1%
# Validation accuracy: 84.8%
# Minibatch loss at step 4250: 0.864979
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.3%
# Minibatch loss at step 4300: 0.711917
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.9%
# Minibatch loss at step 4350: 0.796779
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.0%
# Minibatch loss at step 4400: 0.606770
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.9%
# Minibatch loss at step 4450: 0.686197
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 4500: 0.534742
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.1%
# Minibatch loss at step 4550: 0.770730
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.3%
# Minibatch loss at step 4600: 0.766865
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.1%
# Minibatch loss at step 4650: 1.008426
# Minibatch accuracy: 79.7%
# Validation accuracy: 84.3%
# Minibatch loss at step 4700: 0.604522
# Minibatch accuracy: 89.1%
# Validation accuracy: 84.7%
# Minibatch loss at step 4750: 0.753809
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 4800: 0.598319
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 4850: 0.713611
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.9%
# Minibatch loss at step 4900: 0.639198
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.0%
# Minibatch loss at step 4950: 0.759744
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 5000: 0.926995
# Minibatch accuracy: 79.7%
# Validation accuracy: 84.9%
# Minibatch loss at step 5050: 0.587755
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.0%
# Minibatch loss at step 5100: 0.641809
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.5%
# Minibatch loss at step 5150: 0.666332
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.4%
# Minibatch loss at step 5200: 0.910267
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.2%
# Minibatch loss at step 5250: 0.595542
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.4%
# Minibatch loss at step 5300: 0.536196
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.7%
# Minibatch loss at step 5350: 0.525175
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.2%
# Minibatch loss at step 5400: 0.670401
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.0%
# Minibatch loss at step 5450: 0.678817
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.6%
# Minibatch loss at step 5500: 0.734689
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 5550: 0.539579
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.3%
# Minibatch loss at step 5600: 0.592849
# Minibatch accuracy: 89.1%
# Validation accuracy: 85.7%
# Minibatch loss at step 5650: 0.686874
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.2%
# Minibatch loss at step 5700: 0.620832
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.5%
# Minibatch loss at step 5750: 0.823027
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.7%
# Minibatch loss at step 5800: 0.668186
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 5850: 0.548507
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.8%
# Minibatch loss at step 5900: 0.644912
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.6%
# Minibatch loss at step 5950: 0.665268
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.3%
# Minibatch loss at step 6000: 0.605236
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.9%
# Minibatch loss at step 6050: 0.721366
# Minibatch accuracy: 79.7%
# Validation accuracy: 86.1%
# Minibatch loss at step 6100: 0.936983
# Minibatch accuracy: 76.6%
# Validation accuracy: 85.4%
# Minibatch loss at step 6150: 0.720738
# Minibatch accuracy: 79.7%
# Validation accuracy: 85.6%
# Minibatch loss at step 6200: 0.475896
# Minibatch accuracy: 92.2%
# Validation accuracy: 85.5%
# Minibatch loss at step 6250: 0.586390
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.7%
# Minibatch loss at step 6300: 0.866678
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.8%
# Minibatch loss at step 6350: 0.959089
# Minibatch accuracy: 79.7%
# Validation accuracy: 85.6%
# Minibatch loss at step 6400: 0.631770
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.9%
# Minibatch loss at step 6450: 0.555293
# Minibatch accuracy: 89.1%
# Validation accuracy: 85.8%
# Minibatch loss at step 6500: 0.441125
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.0%
# Minibatch loss at step 6550: 0.812992
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.8%
# Minibatch loss at step 6600: 0.597955
# Minibatch accuracy: 89.1%
# Validation accuracy: 85.5%
# Minibatch loss at step 6650: 0.507912
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.9%
# Minibatch loss at step 6700: 0.566522
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.0%
# Minibatch loss at step 6750: 0.833050
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.5%
# Minibatch loss at step 6800: 0.737917
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.1%
# Minibatch loss at step 6850: 0.518214
# Minibatch accuracy: 92.2%
# Validation accuracy: 86.3%
# Minibatch loss at step 6900: 0.601030
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.1%
# Minibatch loss at step 6950: 0.755374
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.8%
# Minibatch loss at step 7000: 0.620564
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.3%
# Minibatch loss at step 7050: 0.964458
# Minibatch accuracy: 76.6%
# Validation accuracy: 86.1%
# Minibatch loss at step 7100: 0.800653
# Minibatch accuracy: 79.7%
# Validation accuracy: 86.2%
# Minibatch loss at step 7150: 0.647757
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.3%
# Minibatch loss at step 7200: 0.679135
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.4%
# Minibatch loss at step 7250: 0.734033
# Minibatch accuracy: 82.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 7300: 0.877882
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.9%
# Minibatch loss at step 7350: 0.862399
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.4%
# Minibatch loss at step 7400: 0.831290
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.3%
# Minibatch loss at step 7450: 0.709793
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.9%
# Minibatch loss at step 7500: 0.655247
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 7550: 0.482572
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 7600: 0.675789
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.2%
# Minibatch loss at step 7650: 0.573320
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 7700: 0.689592
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.5%
# Minibatch loss at step 7750: 0.626942
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.2%
# Minibatch loss at step 7800: 0.536615
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.3%
# Minibatch loss at step 7850: 0.407809
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 7900: 0.530310
# Minibatch accuracy: 92.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 7950: 0.611244
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 8000: 0.627123
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.5%
# Minibatch loss at step 8050: 0.574446
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.3%
# Minibatch loss at step 8100: 0.648203
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.6%
# Minibatch loss at step 8150: 0.698394
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.7%
# Minibatch loss at step 8200: 0.702433
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.8%
# Minibatch loss at step 8250: 0.648663
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.4%
# Minibatch loss at step 8300: 0.507071
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.6%
# Minibatch loss at step 8350: 0.794804
# Minibatch accuracy: 82.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 8400: 0.517061
# Minibatch accuracy: 92.2%
# Validation accuracy: 86.6%
# Minibatch loss at step 8450: 0.648680
# Minibatch accuracy: 82.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 8500: 0.648807
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.5%
# Minibatch loss at step 8550: 0.581976
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 8600: 0.578231
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.6%
# Minibatch loss at step 8650: 1.008344
# Minibatch accuracy: 73.4%
# Validation accuracy: 86.5%
# Minibatch loss at step 8700: 0.403125
# Minibatch accuracy: 92.2%
# Validation accuracy: 86.7%
# Minibatch loss at step 8750: 0.602793
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.5%
# Minibatch loss at step 8800: 0.589406
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.7%
# Minibatch loss at step 8850: 0.617868
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.0%
# Minibatch loss at step 8900: 0.589456
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.7%
# Minibatch loss at step 8950: 0.810770
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.4%
# Minibatch loss at step 9000: 0.562651
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.0%
# Minibatch loss at step 9050: 0.809945
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.4%
# Minibatch loss at step 9100: 0.583206
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.6%
# Minibatch loss at step 9150: 0.655513
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 9200: 0.642324
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.1%
# Minibatch loss at step 9250: 0.908809
# Minibatch accuracy: 79.7%
# Validation accuracy: 86.6%
# Minibatch loss at step 9300: 1.052631
# Minibatch accuracy: 79.7%
# Validation accuracy: 86.8%
# Minibatch loss at step 9350: 0.805621
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 9400: 0.743485
# Minibatch accuracy: 82.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 9450: 0.728669
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 9500: 0.618219
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.1%
# Minibatch loss at step 9550: 0.502564
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.6%
# Minibatch loss at step 9600: 0.803815
# Minibatch accuracy: 79.7%
# Validation accuracy: 86.8%
# Minibatch loss at step 9650: 0.701029
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 9700: 0.589587
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.8%
# Minibatch loss at step 9750: 0.718775
# Minibatch accuracy: 82.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 9800: 0.621624
# Minibatch accuracy: 82.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 9850: 0.570405
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 9900: 0.516373
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 9950: 0.857776
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.8%
# Minibatch loss at step 10000: 0.538910
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.2%
# Minibatch loss at step 10050: 0.499193
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.1%
# Minibatch loss at step 10100: 0.760649
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 10150: 0.473178
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 10200: 0.730109
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 10250: 0.535351
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.2%
# Minibatch loss at step 10300: 0.634612
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.1%
# Minibatch loss at step 10350: 0.395815
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 10400: 0.641097
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 10450: 0.576135
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 10500: 0.677489
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.8%
# Minibatch loss at step 10550: 0.369432
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 10600: 0.536285
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.8%
# Minibatch loss at step 10650: 0.494627
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 10700: 0.378952
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 10750: 0.627585
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 10800: 0.419785
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 10850: 0.606940
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.6%
# Minibatch loss at step 10900: 0.800519
# Minibatch accuracy: 82.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 10950: 0.644928
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.5%
# Minibatch loss at step 11000: 0.779930
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.1%
# Minibatch loss at step 11050: 0.477946
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 11100: 0.632843
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.3%
# Minibatch loss at step 11150: 0.503710
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.8%
# Minibatch loss at step 11200: 0.363316
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 11250: 0.573951
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.2%
# Minibatch loss at step 11300: 0.413166
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 11350: 0.672038
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.2%
# Minibatch loss at step 11400: 0.537992
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.2%
# Minibatch loss at step 11450: 0.507322
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.5%
# Minibatch loss at step 11500: 0.565683
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.3%
# Minibatch loss at step 11550: 0.524381
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.3%
# Minibatch loss at step 11600: 0.586230
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.3%
# Minibatch loss at step 11650: 0.743438
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.1%
# Minibatch loss at step 11700: 0.593538
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.0%
# Minibatch loss at step 11750: 0.564721
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 11800: 0.705430
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss at step 11850: 0.593312
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 11900: 0.503823
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 11950: 0.540529
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.2%
# Minibatch loss at step 12000: 0.532203
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.5%
# Minibatch loss at step 12050: 0.466001
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.5%
# Minibatch loss at step 12100: 0.629129
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.4%
# Minibatch loss at step 12150: 0.506700
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.4%
# Minibatch loss at step 12200: 0.538217
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.4%
# Minibatch loss at step 12250: 0.612411
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.7%
# Minibatch loss at step 12300: 0.561946
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.5%
# Minibatch loss at step 12350: 0.540405
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.1%
# Minibatch loss at step 12400: 0.618899
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.4%
# Minibatch loss at step 12450: 0.311234
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.7%
# Minibatch loss at step 12500: 0.613551
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.5%
# Minibatch loss at step 12550: 0.395289
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 12600: 0.602548
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.5%
# Minibatch loss at step 12650: 0.655706
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.2%
# Minibatch loss at step 12700: 0.425779
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.7%
# Minibatch loss at step 12750: 0.499527
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.5%
# Minibatch loss at step 12800: 0.402004
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.3%
# Minibatch loss at step 12850: 0.748222
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 12900: 0.819210
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 12950: 0.549344
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 13000: 0.435149
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.7%
# Minibatch loss at step 13050: 0.630310
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 13100: 0.638435
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 13150: 0.541639
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.5%
# Minibatch loss at step 13200: 0.501071
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.6%
# Minibatch loss at step 13250: 0.521300
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 13300: 0.648536
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 13350: 0.552665
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.0%
# Minibatch loss at step 13400: 0.546478
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.4%
# Minibatch loss at step 13450: 0.498095
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.6%
# Minibatch loss at step 13500: 0.458222
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.5%
# Minibatch loss at step 13550: 0.623969
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.4%
# Minibatch loss at step 13600: 0.643113
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.7%
# Minibatch loss at step 13650: 0.674235
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.9%
# Minibatch loss at step 13700: 0.425816
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 13750: 0.550069
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.5%
# Minibatch loss at step 13800: 0.652499
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.9%
# Minibatch loss at step 13850: 0.554671
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.8%
# Minibatch loss at step 13900: 0.393839
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 13950: 0.389491
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.8%
# Minibatch loss at step 14000: 0.503865
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 14050: 0.661152
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.1%
# Minibatch loss at step 14100: 0.465863
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.7%
# Minibatch loss at step 14150: 0.741548
# Minibatch accuracy: 82.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 14200: 0.611588
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.1%
# Minibatch loss at step 14250: 0.463547
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.8%
# Minibatch loss at step 14300: 0.628661
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.9%
# Minibatch loss at step 14350: 0.526624
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.9%
# Minibatch loss at step 14400: 0.609799
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.3%
# Minibatch loss at step 14450: 0.510376
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.0%
# Minibatch loss at step 14500: 0.560504
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.9%
# Minibatch loss at step 14550: 0.470257
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.0%
# Minibatch loss at step 14600: 0.532751
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 14650: 0.611341
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.5%
# Minibatch loss at step 14700: 0.608000
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 14750: 0.301510
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# Minibatch loss at step 14800: 0.698796
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.8%
# Minibatch loss at step 14850: 0.384100
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 14900: 0.680222
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 14950: 0.622036
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 15000: 0.513872
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 15050: 0.670000
# Minibatch accuracy: 82.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 15100: 0.388725
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 15150: 0.643343
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.6%
# Minibatch loss at step 15200: 0.372172
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.0%
# Minibatch loss at step 15250: 0.292851
# Minibatch accuracy: 95.3%
# Validation accuracy: 87.8%
# Minibatch loss at step 15300: 0.633925
# Minibatch accuracy: 82.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 15350: 0.654538
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.9%
# Minibatch loss at step 15400: 0.538634
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 15450: 0.551849
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.7%
# Minibatch loss at step 15500: 0.693490
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.5%
# Minibatch loss at step 15550: 0.443689
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 15600: 0.590696
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.1%
# Minibatch loss at step 15650: 0.693482
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.9%
# Minibatch loss at step 15700: 0.452487
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.9%
# Minibatch loss at step 15750: 0.509426
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.3%
# Minibatch loss at step 15800: 0.633839
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.2%
# Minibatch loss at step 15850: 0.597547
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.8%
# Minibatch loss at step 15900: 0.473514
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.8%
# Minibatch loss at step 15950: 0.515294
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 16000: 0.700696
# Minibatch accuracy: 78.1%
# Validation accuracy: 87.9%
# Minibatch loss at step 16050: 0.521054
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.1%
# Minibatch loss at step 16100: 0.416805
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.2%
# Minibatch loss at step 16150: 0.539453
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.5%
# Minibatch loss at step 16200: 0.263873
# Minibatch accuracy: 98.4%
# Validation accuracy: 88.3%
# Minibatch loss at step 16250: 0.373500
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 16300: 0.355500
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 16350: 0.499237
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 16400: 0.406972
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 16450: 0.403796
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.7%
# Minibatch loss at step 16500: 0.387627
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 16550: 0.405397
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 16600: 0.527392
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 16650: 0.628378
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.0%
# Minibatch loss at step 16700: 0.473385
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 16750: 0.451165
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 16800: 0.583851
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.3%
# Minibatch loss at step 16850: 0.607230
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.5%
# Minibatch loss at step 16900: 0.526752
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 16950: 0.448488
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.7%
# Minibatch loss at step 17000: 0.539761
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.8%
# Minibatch loss at step 17050: 0.387828
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.5%
# Minibatch loss at step 17100: 0.526671
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.3%
# Minibatch loss at step 17150: 0.421880
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.0%
# Minibatch loss at step 17200: 0.664271
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.9%
# Minibatch loss at step 17250: 0.465943
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.0%
# Minibatch loss at step 17300: 0.531206
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.0%
# Minibatch loss at step 17350: 0.442623
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.1%
# Minibatch loss at step 17400: 0.543564
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 17450: 0.416481
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.2%
# Minibatch loss at step 17500: 0.485990
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.6%
# Minibatch loss at step 17550: 0.501468
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 17600: 0.536432
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.2%
# Minibatch loss at step 17650: 0.653595
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.3%
# Minibatch loss at step 17700: 0.440480
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.6%
# Minibatch loss at step 17750: 0.921737
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.2%
# Minibatch loss at step 17800: 0.523918
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 17850: 0.601953
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.4%
# Minibatch loss at step 17900: 0.430149
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 17950: 0.686317
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.4%
# Minibatch loss at step 18000: 0.449408
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.1%
# Minibatch loss at step 18050: 0.452329
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.3%
# Minibatch loss at step 18100: 0.545095
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.6%
# Minibatch loss at step 18150: 0.521841
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.2%
# Minibatch loss at step 18200: 0.485597
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 18250: 0.593543
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.3%
# Minibatch loss at step 18300: 0.943807
# Minibatch accuracy: 78.1%
# Validation accuracy: 88.3%
# Minibatch loss at step 18350: 0.674581
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.1%
# Minibatch loss at step 18400: 0.464860
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.5%
# Minibatch loss at step 18450: 0.574255
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.0%
# Minibatch loss at step 18500: 0.385194
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.4%
# Minibatch loss at step 18550: 0.581475
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss at step 18600: 0.431828
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.2%
# Minibatch loss at step 18650: 0.463850
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss at step 18700: 0.596441
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.3%
# Minibatch loss at step 18750: 0.468863
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.7%
# Minibatch loss at step 18800: 0.291442
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.2%
# Minibatch loss at step 18850: 0.531330
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.5%
# Minibatch loss at step 18900: 0.480179
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 18950: 0.411081
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.4%
# Minibatch loss at step 19000: 0.463285
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.3%
# Minibatch loss at step 19050: 0.497279
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.6%
# Minibatch loss at step 19100: 0.404171
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.2%
# Minibatch loss at step 19150: 0.632441
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.4%
# Minibatch loss at step 19200: 0.582772
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.2%
# Minibatch loss at step 19250: 0.522409
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.7%
# Minibatch loss at step 19300: 0.268940
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.6%
# Minibatch loss at step 19350: 0.340977
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.5%
# Minibatch loss at step 19400: 0.566401
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.1%
# Minibatch loss at step 19450: 0.481980
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.1%
# Minibatch loss at step 19500: 0.525719
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 19550: 0.516021
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.3%
# Minibatch loss at step 19600: 0.588813
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.4%
# Minibatch loss at step 19650: 0.492778
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.3%
# Minibatch loss at step 19700: 0.520719
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.6%
# Minibatch loss at step 19750: 0.302898
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.4%
# Minibatch loss at step 19800: 0.540292
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss at step 19850: 0.458547
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.6%
# Minibatch loss at step 19900: 0.371182
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.5%
# Minibatch loss at step 19950: 0.404488
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.4%
# Minibatch loss at step 20000: 0.315286
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 20050: 0.457240
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.7%
# Minibatch loss at step 20100: 0.318885
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.5%
# Minibatch loss at step 20150: 0.334011
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 20200: 0.380893
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 20250: 0.506066
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.7%
# Minibatch loss at step 20300: 0.515553
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 20350: 0.523037
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.4%
# Minibatch loss at step 20400: 0.554548
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.6%
# Minibatch loss at step 20450: 0.347099
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 20500: 0.512610
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 20550: 0.282916
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.4%
# Minibatch loss at step 20600: 0.720241
# Minibatch accuracy: 82.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 20650: 0.467540
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 20700: 0.525296
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.6%
# Minibatch loss at step 20750: 0.637472
# Minibatch accuracy: 82.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 20800: 0.528180
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.5%
# Minibatch loss at step 20850: 0.629323
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.6%
# Minibatch loss at step 20900: 0.752053
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.1%
# Minibatch loss at step 20950: 0.457546
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 21000: 0.617343
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.7%
# Minibatch loss at step 21050: 0.484562
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.6%
# Minibatch loss at step 21100: 0.661941
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 21150: 0.339323
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.4%
# Minibatch loss at step 21200: 0.623078
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.4%
# Minibatch loss at step 21250: 0.466434
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.5%
# Minibatch loss at step 21300: 0.442994
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.5%
# Minibatch loss at step 21350: 0.380384
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.5%
# Minibatch loss at step 21400: 0.415931
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.9%
# Minibatch loss at step 21450: 0.345444
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.6%
# Minibatch loss at step 21500: 0.415074
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.7%
# Minibatch loss at step 21550: 0.462706
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# Minibatch loss at step 21600: 0.479048
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.0%
# Minibatch loss at step 21650: 0.449437
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 21700: 0.493547
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.5%
# Minibatch loss at step 21750: 0.553032
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.5%
# Minibatch loss at step 21800: 0.539874
# Minibatch accuracy: 82.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 21850: 0.916263
# Minibatch accuracy: 78.1%
# Validation accuracy: 88.8%
# Minibatch loss at step 21900: 0.543946
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.8%
# Minibatch loss at step 21950: 0.456070
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 22000: 0.438275
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 22050: 0.478034
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 22100: 0.454833
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.6%
# Minibatch loss at step 22150: 0.458634
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.9%
# Minibatch loss at step 22200: 0.831161
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.1%
# Minibatch loss at step 22250: 0.406072
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.7%
# Minibatch loss at step 22300: 0.445665
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 22350: 0.417716
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.8%
# Minibatch loss at step 22400: 0.413916
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.8%
# Minibatch loss at step 22450: 0.537856
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.6%
# Minibatch loss at step 22500: 0.617421
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.7%
# Minibatch loss at step 22550: 0.385556
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.5%
# Minibatch loss at step 22600: 0.522090
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 22650: 0.253083
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.8%
# Minibatch loss at step 22700: 0.453622
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# Minibatch loss at step 22750: 0.446359
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.6%
# Minibatch loss at step 22800: 0.353073
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.6%
# Minibatch loss at step 22850: 0.506711
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.5%
# Minibatch loss at step 22900: 0.438081
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 22950: 0.382641
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.5%
# Minibatch loss at step 23000: 0.486381
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
# Minibatch loss at step 23050: 0.477696
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 23100: 0.450218
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.6%
# Minibatch loss at step 23150: 0.470236
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.3%
# Minibatch loss at step 23200: 0.353805
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 23250: 0.460607
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.0%
# Minibatch loss at step 23300: 0.487639
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 23350: 0.436377
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# Minibatch loss at step 23400: 0.649312
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 23450: 0.499738
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.9%
# Minibatch loss at step 23500: 0.347919
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 23550: 0.468193
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.7%
# Minibatch loss at step 23600: 0.313201
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 23650: 0.522919
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.0%
# Minibatch loss at step 23700: 0.500618
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.8%
# Minibatch loss at step 23750: 0.520747
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.7%
# Minibatch loss at step 23800: 0.756884
# Minibatch accuracy: 78.1%
# Validation accuracy: 88.8%
# Minibatch loss at step 23850: 0.556185
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 23900: 0.531852
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.2%
# Minibatch loss at step 23950: 0.393568
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.8%
# Minibatch loss at step 24000: 0.465993
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.2%
# Minibatch loss at step 24050: 0.686850
# Minibatch accuracy: 82.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 24100: 0.544377
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.5%
# Minibatch loss at step 24150: 0.423277
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.8%
# Minibatch loss at step 24200: 0.390663
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.9%
# Minibatch loss at step 24250: 0.604897
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.7%
# Minibatch loss at step 24300: 0.307383
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.8%
# Minibatch loss at step 24350: 0.455079
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.7%
# Minibatch loss at step 24400: 0.424448
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.1%
# Minibatch loss at step 24450: 0.394898
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 24500: 0.441940
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
# Minibatch loss at step 24550: 0.513972
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 24600: 0.453622
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# Minibatch loss at step 24650: 0.326606
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 24700: 0.540896
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 24750: 0.543979
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.7%
# Minibatch loss at step 24800: 0.539040
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 24850: 0.546609
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# Minibatch loss at step 24900: 0.379143
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
# Minibatch loss at step 24950: 0.501511
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.1%
# Minibatch loss at step 25000: 0.415141
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.7%
# Minibatch loss at step 25050: 0.453127
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.5%
# Minibatch loss at step 25100: 0.410785
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
# Minibatch loss at step 25150: 0.375943
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 25200: 0.307607
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 25250: 0.423798
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.0%
# Minibatch loss at step 25300: 0.277985
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.0%
# Minibatch loss at step 25350: 0.462512
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 25400: 0.476526
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.7%
# Minibatch loss at step 25450: 0.572194
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.7%
# Minibatch loss at step 25500: 0.427153
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.7%
# Minibatch loss at step 25550: 0.452797
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 25600: 0.296486
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 25650: 0.342926
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.5%
# Minibatch loss at step 25700: 0.636712
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.8%
# Minibatch loss at step 25750: 0.345151
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.2%
# Minibatch loss at step 25800: 0.485858
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 25850: 0.594909
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.9%
# Minibatch loss at step 25900: 0.398656
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.1%
# Minibatch loss at step 25950: 0.528271
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.0%
# Minibatch loss at step 26000: 0.346486
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 26050: 0.451350
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.5%
# Minibatch loss at step 26100: 0.606812
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# Minibatch loss at step 26150: 0.350511
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 26200: 0.474040
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 26250: 0.368685
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.0%
# Minibatch loss at step 26300: 0.421309
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# Minibatch loss at step 26350: 0.560997
# Minibatch accuracy: 82.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 26400: 0.219027
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.3%
# Minibatch loss at step 26450: 0.396210
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# Minibatch loss at step 26500: 0.400564
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.7%
# Minibatch loss at step 26550: 0.508137
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.0%
# Minibatch loss at step 26600: 0.455716
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# Minibatch loss at step 26650: 0.607555
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.8%
# Minibatch loss at step 26700: 0.312921
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 26750: 0.395241
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.7%
# Minibatch loss at step 26800: 0.424652
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.1%
# Minibatch loss at step 26850: 0.475636
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 26900: 0.466986
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 26950: 0.506241
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# Minibatch loss at step 27000: 0.383298
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# Minibatch loss at step 27050: 0.350894
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.2%
# Minibatch loss at step 27100: 0.435818
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.0%
# Minibatch loss at step 27150: 0.410724
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.1%
# Minibatch loss at step 27200: 0.373583
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# Minibatch loss at step 27250: 0.407634
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# Minibatch loss at step 27300: 0.493149
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.0%
# Minibatch loss at step 27350: 0.482392
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.9%
# Minibatch loss at step 27400: 0.510692
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.1%
# Minibatch loss at step 27450: 0.317950
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 27500: 0.554114
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 27550: 0.297418
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 27600: 0.316777
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.8%
# Minibatch loss at step 27650: 0.434568
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.0%
# Minibatch loss at step 27700: 0.482187
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.1%
# Minibatch loss at step 27750: 0.639520
# Minibatch accuracy: 79.7%
# Validation accuracy: 89.2%
# Minibatch loss at step 27800: 0.533440
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.3%
# Minibatch loss at step 27850: 0.356976
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 27900: 0.453870
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.4%
# Minibatch loss at step 27950: 0.711429
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.2%
# Minibatch loss at step 28000: 0.448351
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# Minibatch loss at step 28050: 0.532481
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.9%
# Minibatch loss at step 28100: 0.343898
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.1%
# Minibatch loss at step 28150: 0.463335
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# Minibatch loss at step 28200: 0.417990
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.1%
# Minibatch loss at step 28250: 0.323503
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 28300: 0.600415
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.5%
# Minibatch loss at step 28350: 0.598437
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.3%
# Minibatch loss at step 28400: 0.448871
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# Minibatch loss at step 28450: 0.432473
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# Minibatch loss at step 28500: 0.334436
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# Minibatch loss at step 28550: 0.272329
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.4%
# Minibatch loss at step 28600: 0.512944
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.9%
# Minibatch loss at step 28650: 0.476964
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 28700: 0.544318
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.8%
# Minibatch loss at step 28750: 0.247115
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.2%
# Minibatch loss at step 28800: 0.257693
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.1%
# Minibatch loss at step 28850: 0.573506
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.0%
# Minibatch loss at step 28900: 0.338603
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.9%
# Minibatch loss at step 28950: 0.625100
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.1%
# Minibatch loss at step 29000: 0.437366
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# Minibatch loss at step 29050: 0.379969
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# Minibatch loss at step 29100: 0.286549
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 29150: 0.305895
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 29200: 0.365174
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 29250: 0.527179
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 29300: 0.450740
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# Minibatch loss at step 29350: 0.533074
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.3%
# Minibatch loss at step 29400: 0.479844
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 29450: 0.288456
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.2%
# Minibatch loss at step 29500: 0.493203
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.0%
# Minibatch loss at step 29550: 0.389499
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.4%
# Minibatch loss at step 29600: 0.410309
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.1%
# Minibatch loss at step 29650: 0.449716
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 29700: 0.446305
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.2%
# Minibatch loss at step 29750: 0.336343
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.1%
# Minibatch loss at step 29800: 0.227582
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# Minibatch loss at step 29850: 0.542480
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.2%
# Minibatch loss at step 29900: 0.531559
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 29950: 0.549567
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.5%
# Minibatch loss at step 30000: 0.317054
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.3%
# Minibatch loss at step 30050: 0.659999
# Minibatch accuracy: 78.1%
# Validation accuracy: 89.1%
# Minibatch loss at step 30100: 0.342336
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.6%
# Minibatch loss at step 30150: 0.336652
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 30200: 0.369722
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.5%
# Minibatch loss at step 30250: 0.490987
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 30300: 0.409281
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 30350: 0.537769
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 30400: 0.677939
# Minibatch accuracy: 79.7%
# Validation accuracy: 89.2%
# Minibatch loss at step 30450: 0.333560
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.4%
# Minibatch loss at step 30500: 0.434338
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# Minibatch loss at step 30550: 0.617092
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# Minibatch loss at step 30600: 0.446680
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 30650: 0.385286
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# Minibatch loss at step 30700: 0.356052
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# Minibatch loss at step 30750: 0.504776
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.0%
# Minibatch loss at step 30800: 0.432410
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.4%
# Minibatch loss at step 30850: 0.439732
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 30900: 0.368320
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# Minibatch loss at step 30950: 0.334191
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.3%
# Minibatch loss at step 31000: 0.419875
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.4%
# Minibatch loss at step 31050: 0.719595
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.3%
# Minibatch loss at step 31100: 0.416147
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.0%
# Minibatch loss at step 31150: 0.493247
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.1%
# Minibatch loss at step 31200: 0.389669
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# Test accuracy: 94.9%
